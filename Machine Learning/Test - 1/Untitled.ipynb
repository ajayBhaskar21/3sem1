# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [100, 20, 25, 40]

mymodel = np.polyfit(x, y, 3)
myline = np.linspace(1, 4, 100)


plt.scatter(x, y)
plt.plot(myline,np.polyval(mymodel, myline))
plt.show()
